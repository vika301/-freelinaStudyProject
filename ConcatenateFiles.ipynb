# %%
import numpy as np
import pandas as pd
import glob
import os


#add path to your stored files; here its the current directory
path = os.getcwd()

#give path and name result file
savepath=os.getcwd(r'Concatinated.csv')
#concatinate your files
all_files = glob.glob(os.path.join(path, "*.csv"))
df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
display(df)
#count duplicates
dup= df.duplicated()
dup.value_counts()
#save condatinated dataset in new path
df.to_csv(savepath, index=False, header=True)
# Out:
#                        id  timestamp_utc           local_time  \
# 0     1533068008196915200     1654346870  2022-06-04T12:47:50
# 1     1532701716386283520     1654259540  2022-06-03T12:32:20
# 2     1533066066183741442     1654346407  2022-06-04T12:40:07
# 3     1532369284319653890     1654180282  2022-06-02T14:31:22
# 4     1533063537614114818     1654345804  2022-06-04T12:30:04
# ...                   ...            ...                  ...
# 5641  1546597214260183040     1657572484  2022-07-11T20:48:04
# 5642  1546596489463472130     1657572312  2022-07-11T20:45:12
# 5643  1546596124139700226     1657572225  2022-07-11T20:43:45
# 5644  1546584754958606339     1657569514  2022-07-11T19:58:34
# 5645  1546450014985125890     1657537389  2022-07-11T11:03:09
#
#      user_screen_name                                               text  \
# 0               icsft  RT @GulfCentre4HR: #SaudiArabia: Free social m...
# ...
